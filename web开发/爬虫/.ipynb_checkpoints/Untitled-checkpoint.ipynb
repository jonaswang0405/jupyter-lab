# %%
url='https://www.nvc-lighting.com.cn/'
response=requests.get(url,timeout=30)
print(response.encoding)   #http的header中猜测出来的编码方式
print(response.apparent_encoding) #推荐编码
response.encoding='utf-8'  #提取utf-8编码
#print(response.text) 
#print(response.content)  #获取二进制数据
#print(response.headers) #获取头部信息
#print(response.raise_for_status()) #如果状态不是200，则返回request.HTTPError类型
# Out:
# ISO-8859-1
# utf-8

# %%
import requests
from bs4 import BeautifulSoup
r=requests.get('https://spine.pk/',timeout=10)
encod=r.apparent_encoding
r.encoding=encod
print(r.status_code)
soup=BeautifulSoup(r.text)
for title in soup.find_all('title'):
    print(title.text)
# Out:
# 200
# spine – engineering

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(response.text,'lxml')
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# Input In [22], in <module>
#       1 from bs4 import BeautifulSoup
# ----> 2 soup=BeautifulSoup(response.text,'lxml')
#
# File C:\Python39\lib\site-packages\bs4\__init__.py:245, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     243     builder_class = builder_registry.lookup(*features)
#     244     if builder_class is None:
# --> 245         raise FeatureNotFound(
#     246             "Couldn't find a tree builder with the features you "
#     247             "requested: %s. Do you need to install a parser library?"
#     248             % ",".join(features))
#     250 # At this point either we have a TreeBuilder instance in
#     251 # builder, or we have a builder_class that we can instantiate
#     252 # with the remaining **kwargs.
# ...

# %% [markdown]
# ## 构建cookies用requests.cookies.cookiejar_from_dict(cookies_dict)方法可行

# %%
cookies='BIDUPSID=A170A43B743AF14D9377CFEF98E86D8E; PSTM=1620375168; BD_UPN=12314753; __yjs_duid=1_6e97cb1522e76ae9b15b5c286673d7571620377629947; H_WISE_SIDS=110085_127969_164869_168389_174661_175536_175755_176120_176399_176556_176678_177167_177259_177371_177408_177950_178140_178327_178381_178444_178494_178631_178703_178771_178794_178947_179335_179341_179345_179392_179399_179462_179521_179575_179595_180110_180119_180183_180299_180324_180407_180565_180606_180654_180670_180699_180752_180754_180758_180822_180890_180931; BAIDUID=950DBF634778F37F1BA4F601B71E04F2:FG=1; MCITY=-:; BDORZ=B490B5EBF6F3CD402E515D22BCDA1598; BDSFRCVID=vLtOJeC627f2X3vHhIWbviiJEgN-YC3TH6ao0A_QOg9Xr5JDQrhCEG0P-x8g0KubGXVWogKK3gOTH4PF_2uxOjjg8UtVJeC6EG0Ptf8g0f5; H_BDCLCKID_SF=tRk8oIL2fIvbfP0k-J32h-QH-UnLetJXf2og2p7F54nKDp0xWtJ13MkJeJrp-tc0WeT2KMjeJbOxsMTsQj0VXfo35HJ7QMKLQDvK0PON3KJmfh7aLR7P0Kue2bb32-biWb7M2MbdJUJP_IoG2Mn8M4bb3qOpBtQmJeTxoUJ25DnJhhCGe6thj5jBjH-saRJ0bIIX3JjV5PK_Hn7zenrDQx4pbt-qJj37fgTg_qnSWlTGfRTYyxoJXCu4LNbnBT5Ka5IL0xn4y4FajD0CWfJ-0-0kQN3TexuO5bRiL66SaC8KDn3oyTbJXp0njb3ly5jtMgOBBJ0yQ4b4OR5JjxonDh83bG7MJPKtfJkt_I_KJC83jtOY5-__-4_tbh_X5-RLfacaVp7F5l8-hCbSeMo6jxkJyJOL-tc0WeTM2j6w0KOxOKQphn_Vbqkw
AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAABSWQGEUlkBhR; BDUSS_BFESS=kFUQWZZR0hUSE1qVU90RzBYR1NGVFVPbC1YY2VCaFdLcXptZkhNYTM0Y1VJMmhoSVFBQUFBJCQAAAAAAAAAAAEAAACPCdswd2pxamVhbgAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAABSWQGEUlkBhR; H_PS_PSSID=34653_34528_34145_34554_33848_34524_34584_34092_26350_34627_34421_34556; BA_HECTOR=ah20a00ka4048524ut1gk15hg0r; ab_sr=1.0.1_ZjNmZjJlNzQzNjIzN2Q1YWIzMmViNTU1NGU5ZTI1ZGQxZDI4OGM2MGY3N2M1Nzg5NTdkNGMyZjYyZjM0MDcyYTAyZTRkNTA4ZGFiZTM4OGIxY2I1ZTE1NTgxMWI1N2QxYzI5ZTBiMTg1ZjAxZjM3NWM4NDkxMTM4ODZiYjEzOGI1MjI5MTJmY2Q3ZjI2YTljOTM3OGUyZWFiMmMxOTcyYw=='
headers={'Host':'www.baidu.com',
         'Referer':'https://www.baidu.com/',
         'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.63 Safari/537.36'}
cookies_dict={}

for ck in cookies.split(';'):
    key,value=ck.split('=',1)
    cookies_dict.update({key:value})
cookies_jar=requests.cookies.cookiejar_from_dict(cookies_dict)
response=requests.get(url,headers=headers,cookies=cookies_jar)
print(response.status_code)
在使用post进行访问时，data内的值要尽量多加一些，不然虽然访问成功，但会拿不到结果。
如果页面成功访问，则返回的结果为network中的preview的值，而并非整个html的内容
# Out:
# 200

# %% [markdown]
# ![微信图片_20210916175344.png](attachment:c5b3a778-4c5e-4ed4-bea1-0fd2818e5605.png)

# %% [markdown]
# # beautifulesoup

# %% [markdown]
# ### 安装：pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(demo,'html.parse')
print(soup.prettify()) #print出来的文本结构清晰
soup.a.name  #获取第一个a标签的名称
soup.a.parent #获取a标签的父对象
tag=soupt.a
tag.attrs #获取a标签对象的属性
soup.a.string #获取a标签的文本属性

soup.a.contents#子节点的列表，将tag所有子节点存入列表
soup.a.children #子节点的迭代类型，循环遍历子节点
soup.a.descendants #子孙节点的迭代类型，包含所有子孙节点
soup.body.contents
soup.a.parent #父辈标签
soup.a.parents #所有父辈标签
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <module>
#       1 from bs4 import BeautifulSoup
# ----> 2 soup=BeautifulSoup(demo,'html.parse')
#       3 print(soup.prettify()) #print出来的文本结构清晰
#       4 soup.a.name  #获取第一个a标签的名称
#
# NameError: name 'demo' is not defined

# %% [markdown]
# ### 平行遍历
# .next_sibling   #下一个平行节点标签
# .previous_sibling    #上一个平行节点标签
# .next_siblings       #后续所有平行标签
# .previous_sibling    #前序所有平行标签
# 例：soup.a.next_sibling

# %%
soup.find_all('p','course') #查找p标签，属性值=courese
soup.find_all(id='link1')
soup.find_all(id=re.compile('link')) #查找所有id含有link开始的所有标签
soup.find_all('a',recursive=False) #recursive=True对soup的所有子孙路径查找a标签，False，只对当前子标签进行查找
soup.find_all(string='abc')  #查找值为abc的内容
soup.find_all=soup()
<tag>.find_all==<tag>()

# %%
扩展find方法
<>.find() #只返回一个结果
<>.find_parents()    #返回多个结果
<>.find_parten()  #只返回一个结果
<>.find_next_siblings()
<>.find_next_sibling()   #只返回一个结果
<>.find_previou_siblings() 
<>.find_previou_sibling()  #只返回一个结果

_180606_180654_180670_180699_180752_180754_180758_180822_180890_180931; BAIDUID=950DBF634778F37F1BA4F601B71E04F2:FG=1; MCITY=-:; BDORZ=B490B5EBF6F3CD402E515D22BCDA1598; BDSFRCVID=vLtOJeC627f2X3vHhIWbviiJEgN-YC3TH6ao0A_QOg9Xr5JDQrhCEG0P-x8g0KubGXVWogKK3gOTH4PF_2uxOjjg8UtVJeC6EG0Ptf8g0f5; H_BDCLCKID_SF=tRk8oIL2fIvbfP0k-J32h-QH-UnLetJXf2og2p7F54nKDp0xWtJ13MkJeJrp-tc0WeT2KMjeJbOxsMTsQj0VXfo35HJ7QMKLQDvK0PON3KJmfh7aLR7P0Kue2bb32-biWb7M2MbdJUJP_IoG2Mn8M4bb3qOpBtQmJeTxoUJ25DnJhhCGe6thj5jBjH-saRJ0bIIX3JjV5PK_Hn7zenrDQx4pbt-qJj37fgTg_qnSWlTGfRTYyxoJXCu4LNbnBT5Ka5IL0xn4y4FajD0
# ...

# %%
url='http://passport.baidu.com/'
headers={'Host':'passport.baidu.com',
         'Referer':'https://passport.baidu.com/v6/ucenter?_t=1631719498',
         'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.63 Safari/537.36'}

response=requests.get(url,cookies=cookies_jar)
print(response.encoding)   #http的header中猜测出来的编码方式
print(response.apparent_encoding) #推荐编码
response.encoding='utf-8'  #提取utf-8编码
text=response.text
print(text.title())
# Out:
# ISO-8859-1
# utf-8
#
#
#
#
#
#
#
#
#
#
# <!Doctype Html>
# <Html>
# <!--Status Ok-->
# <Head>
# <Meta Http-Equiv="Content-Type" Content="Text/Html; Charset=Utf-8" />
# <Meta Name="Description" Content="百度帐号是登录所有百度系产品的通行证，登录后还可以在帐户管理页管理/修改您的个人信息，包括修改密码、绑定手机、身份认证等">
# <Title>
# 登录百度帐号
# </Title>
# <Link Rel="Shortcut Icon" Href="Https://Www.Baidu.Com/Favicon.Ico" Type="Image/X-Icon" />
# <Link Rel="Icon" Sizes="Any" Mask Href="Https://Www.Baidu.Com/Img/Baidu.Svg">                <Script Type="Text/Javascript" Nonce="Ghw65Rnechlc1E2J">
#             Window.Wpo={Start:New Date*1,Pid:109,Page:'Passport'};
#             Var _Hmt = _Hmt || [];
#         </Script><Link Href="Https://Ppui-Static-Pc.Cdn.Bcebos.Com/Static/Passpc-Base/Css/Base.Css?Cdnversion=1631720773" Type="Text/Css" Rel="Stylesheet" />        <Link Href="Https://Ppui-Static-Pc.Cdn.Bcebos.Com/Static/Passpc-Base/Css/Ui/Ui.Css?Cdnversion=1631720773" Type="Text/Css" Rel="Stylesheet" />
# ...

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(text,'lxml')
#print(soup.prettify()) #print出来的文本结构清晰
soup.a.parent #获取a标签的父对象
for x in soup.find_all('a'):
    print(x.string)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <module>
#       1 from bs4 import BeautifulSoup
# ----> 2 soup=BeautifulSoup(text,'lxml')
#       3 #print(soup.prettify()) #print出来的文本结构清晰
#       4 soup.a.parent #获取a标签的父对象
#
# NameError: name 'text' is not defined

# %%
from time import perf_counter
a=perf_counter()
for x in range(90000):
    b=x
perf_counter()-a
# Out:
# 0.00363869999999622

# %%
from Cpython.Build import cythonize
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <module>
# ----> 1 from Cpython.Build import cythonize
#
# ModuleNotFoundError: No module named 'Cpython'
