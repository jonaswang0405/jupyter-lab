# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

plt.figure(figsize=(12, 12))

n_samples = 1500
random_state = 170
X, y = make_blobs(n_samples=n_samples, random_state=random_state) #此步构建数据

# Incorrect number of clusters
y_pred = KMeans(n_clusters=2, random_state=random_state).fit_predict(X)  #直接预测，fit_predict=fit(x).predict(x),效率上更高一些

plt.subplot(221)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.title("Incorrect Number of Blobs")

# Anisotropicly distributed data
transformation = [[0.60834549, -0.63667341], [-0.40887718, 0.85253229]]
X_aniso = np.dot(X, transformation)
y_pred = KMeans(n_clusters=3, random_state=random_state).fit_predict(X_aniso)

plt.subplot(222)
plt.scatter(X_aniso[:, 0], X_aniso[:, 1], c=y_pred)
plt.title("Anisotropicly Distributed Blobs")

# Different variance
X_varied, y_varied = make_blobs(n_samples=n_samples,
                                cluster_std=[1.0, 2.5, 5],
                                random_state=random_state)
y_pred = KMeans(n_clusters=3, random_state=random_state).fit_predict(X_varied)

plt.subplot(223)
plt.scatter(X_varied[:, 0], X_varied[:, 1], c=y_pred)
plt.title("Unequal Variance")

# Unevenly sized blobs
X_filtered = np.vstack((X[y == 0][:500], X[y == 1][:100], X[y == 2][:10]))
y_pred = KMeans(n_clusters=3,
                random_state=random_state).fit_predict(X_filtered)

plt.subplot(224)
plt.scatter(X_filtered[:, 0], X_filtered[:, 1], c=y_pred)
plt.title("Unevenly Sized Blobs")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

plt.figure(figsize=(12, 12))

n_samples = 1500
random_state = 170
X, y = make_blobs(n_samples=n_samples, random_state=random_state) #此步构建数据



# Anisotropicly distributed data
transformation = [[0.6, -0.6], [-0.4, 0.8]]
X_aniso = np.dot(X, transformation)
tf = [[-0.6,-0.6], [0.8, 0.4]]
x_t = np.dot(X_aniso, tf)
y_pred = KMeans(n_clusters=3, random_state=random_state).fit_predict(x_t)

plt.subplot(222)
plt.scatter(X_aniso[:, 0], X_aniso[:, 1], c=y_pred)
plt.title("Anisotropicly Distributed Blobs")

plt.show()

# %%
no_structure = np.random.rand(n_samples, 2), None

# %%
mixture
# Out:
# <module 'sklearn.mixture' from 'c:\\python39\\lib\\site-packages\\sklearn\\mixture\\__init__.py'>

# %%
x=np.array([[1,2],[3,4]])
tf=np.array([[1,2],[0,0]])
np.dot(x,transformation)
# Out:
# array([[-0.2,  1. ],
#        [ 0.2,  1.4]])

# %%
transformation
# Out:
# [[0.6, -0.6], [-0.4, 0.8]]

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
x=np.array([[1,1],[1,2],[2,2],[2,3]])
y=np.dot(x,np.array([[1,2],[2,3]]))+3
reg=LinearRegression(positive=True).fit(x,y)
print(reg)
print(reg.coef_)
reg.predict(np.array([[3,5]]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-dc23a70b6366> in <module>
#       3 x=np.array([[1,1],[1,2],[2,2],[2,3]])
#       4 y=np.dot(x,np.array([[1,2],[2,3]]))+3
# ----> 5 reg=LinearRegression(positive=True).fit(x,y)
#       6 print(reg)
#       7 print(reg.coef_)
#
# c:\python39\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     541                         delayed(optimize.nnls)(X, y[:, j])
#     542                         for j in range(y.shape[1]))
# --> 543                 self.coef_, self._residues =map(np.vstack, zip(*outs))
#     544         elif sp.issparse(X):
#     545             X_offset_scale = X_offset / X_scale
#
# TypeError: cannot unpack non-iterable int object

# %%
y.ndim
# Out:
# 1

# %%
x
# Out:
# array([[1, 1],
#        [1, 2],
#        [2, 2],
#        [2, 3]])

# %%
np.array([[1,2],[2,3]])
# Out:
# array([[1, 2],
#        [2, 3]])
